# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Análise Exploratória de Dados de Logística II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Manipulação;</li>
#   <li>Visualização;</li>
#   <li>Storytelling.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# Este *notebook* deve servir como um guia para **você continuar** a construção da sua própria análise exploratória de dados. Fique a vontate para copiar os códigos da aula mas busque explorar os dados ao máximo. Por fim, publique seu *notebook* no [Kaggle](https://www.kaggle.com/devforcemax).

# %% [markdown]
# ---

# %% [markdown]
# # **Análise Exploratória de Dados de Logística**

# %% [markdown]
# ## 1\. Contexto

# %% [markdown]
# Realização da Análise Exploratória de Dados de Logística da empresa Loggi utilizando a região de Brasilia-DF.
#
# Abaixo estão situados todo o passo a passo da construção das linhas de código, construção dos gráficos, análise das situações e suas possiveis soluções.

# %% [markdown]
# ## 2\. Pacotes e bibliotecas

# %%
# importe todas as suas bibliotecas aqui, siga os padrões do PEP8:
#
# - 1º pacotes nativos do python: json, os, etc.;
# - 2º pacotes de terceiros: pandas, seabornm etc.;
# - 3º pacotes que você desenvolveu.
#

# !pip install geopy
# !pip install geopandas
# !pip install geobr
# !pip install descartes

import pandas as pd
import requests
import seaborn as sns
import geopandas as gpd
import geobr
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# Requirement already satisfied: geopy in c:\users\halisson\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\halisson\anaconda3\lib\site-packages (from geopy) (2.0)
# Requirement already satisfied: geopandas in c:\users\halisson\anaconda3\lib\site-packages (0.14.3)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\halisson\anaconda3\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\halisson\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\halisson\anaconda3\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\halisson\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\halisson\anaconda3\lib\site-packages (from geopandas) (1.8.5.post1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\halisson\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\halisson\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\halisson\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\halisson\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (1.24.3)
# Requirement already satisfied: colorama in c:\users\halisson\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: geobr in c:\users\halisson\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: geopandas<0.15.0,>=0.14.0 in c:\users\halisson\anaconda3\lib\site-packages (from geobr) (0.14.3)
# Requirement already satisfied: lxml<6.0.0,>=5.1.0 in c:\users\halisson\anaconda3\lib\site-packages (from geobr) (5.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in c:\users\halisson\anaconda3\lib\site-packages (from geobr) (2.31.0)
# Requirement already satisfied: shapely<2.0.0,>=1.7.0 in c:\users\halisson\anaconda3\lib\site-packages (from geobr) (1.8.5.post1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\halisson\anaconda3\lib\site-packages (from geopandas<0.15.0,>=0.14.0->geobr) (1.9.5)
# Requirement already satisfied: packaging in c:\users\halisson\anaconda3\lib\site-packages (from geopandas<0.15.0,>=0.14.0->geobr) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\halisson\anaconda3\lib\site-packages (from geopandas<0.15.0,>=0.14.0->geobr) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\halisson\anaconda3\lib\site-packages (from geopandas<0.15.0,>=0.14.0->geobr) (3.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\halisson\anaconda3\lib\site-packages (from requests<3.0.0,>=2.25.1->geobr) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\halisson\anaconda3\lib\site-packages (from requests<3.0.0,>=2.25.1->geobr) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\halisson\anaconda3\lib\site-packages (from requests<3.0.0,>=2.25.1->geobr) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\halisson\anaconda3\lib\site-packages (from requests<3.0.0,>=2.25.1->geobr) (2024.2.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (22.1.0)
# Requirement already satisfied: click~=8.0 in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (0.7.2)
# Requirement already satisfied: six in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\halisson\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\halisson\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas<0.15.0,>=0.14.0->geobr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\halisson\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas<0.15.0,>=0.14.0->geobr) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\halisson\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas<0.15.0,>=0.14.0->geobr) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\halisson\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas<0.15.0,>=0.14.0->geobr) (1.24.3)
# Requirement already satisfied: colorama in c:\users\halisson\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (0.4.6)
# Requirement already satisfied: descartes in c:\users\halisson\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: matplotlib in c:\users\halisson\anaconda3\lib\site-packages (from descartes) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\halisson\anaconda3\lib\site-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\halisson\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.16.0)

# %% [markdown]
# ## 3\. Exploração de dados

# %%
# faça o código de exploração de dados:
#
# - coleta de dados;
# - wrangling da estrutura;
# - exploração do schema;
# - etc.


url = 'https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/deliveries.json'
nome_arquivo = 'deliveries.json'
aux = requests.get(url)
with open(nome_arquivo, 'wb') as fp:
    fp.write(aux.content)

url = 'https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/dataset/deliveries-geodata.csv'
nome_arquivo = 'deliveries-geodata.csv'
aux = requests.get(url)
with open(nome_arquivo, 'wb') as fp:
    fp.write(aux.content)

df_bases = pd.read_json("deliveries.json")
df_entregas = pd.read_csv("deliveries-geodata.csv", header = 0)

# %% [markdown]
# ## 4\. Manipulação

# %%
# faça o código de manipulação de dados:
#
# - enriquecimento;
# - controle de qualidade;
# - etc.

df_bases = pd.merge(left=df_bases, right=df_entregas, how="inner", left_index=True, right_index=True)
df_bases_normalized= pd.json_normalize(df_bases["origin"])
df_bases = pd.merge(left=df_bases, right=df_bases_normalized, how="inner", left_index=True, right_index=True)

df_bases = df_bases.drop(["origin", "delivery_lat", "delivery_lng"], axis=1)
df_bases = df_bases.rename(columns={
"name":"Nome",
"region": "Base",
"vehicle_capacity":"Capacidade_Veiculo",
"deliveries":"Entregas",
"lng":"lng_base",
"lat":"lat_base",
"delivery_city": "Cidade_entrega",
"delivery_suburb":"Região_entrega"
})

df_bases = df_bases[["Nome", "Base", "lng_base", "lat_base", "Cidade_entrega", "Região_entrega","Capacidade_Veiculo", "Entregas"]]
bases_exploded = df_bases[["Entregas"]].explode("Entregas")
bases_exploded = pd.concat([
    pd.DataFrame(bases_exploded["Entregas"].apply(lambda extrair: extrair["size"])).rename(columns={"Entregas":"Tamanho_Entrega"}),
    pd.DataFrame(bases_exploded["Entregas"].apply(lambda extrair: extrair["point"]["lng"])).rename(columns={"Entregas":"lng_entrega"}),
    pd.DataFrame(bases_exploded["Entregas"].apply(lambda extrair: extrair["point"]["lat"])).rename(columns={"Entregas":"lat_entrega"}),
],axis=1)

df_bases = df_bases.drop("Entregas", axis=1)
df_bases = pd.merge(left=df_bases, right=bases_exploded, how="right", left_index=True, right_index=True)
df_bases.reset_index(inplace=True, drop=True)

#Método fillna para detectar e remover valores nulos.
df_bases[["Cidade_entrega", "Região_entrega"]] = df_bases[["Cidade_entrega", "Região_entrega"]].fillna("Indisponível")

# %% [markdown]
# ## 5\. Visualização

# %%
# faça o código de visualização de dados:
#
# - produza pelo menos duas visualizações;
# - adicione um pequeno texto com os insights encontrados;
# - etc.

mapa_distrito_federal = geobr.read_municipality(code_muni='DF', year=2020)

geo_base = df_bases[["Base", "lng_base", "lat_base"]].drop_duplicates().reset_index(drop= True)
geo_base_df = gpd.GeoDataFrame( geo_base, geometry=gpd.points_from_xy( geo_base["lng_base"], geo_base["lat_base"] ) )

geo_entregas_df = gpd.GeoDataFrame(df_bases, geometry=gpd.points_from_xy(df_bases["lng_entrega"], df_bases["lat_entrega"]))

total_entregas = df_bases['Tamanho_Entrega'].sum()

total_entregas_base = df_bases[['Base', 'Tamanho_Entrega']].groupby("Base").agg("sum").reset_index()
total_entregas_base ['porcentagem_total_entregas'] = round(total_entregas_base ['Tamanho_Entrega'] / total_entregas, 2)
total_entregas_base.rename(columns={'Tamanho_Entrega':'total_base', "Base":"região"}, inplace=True)
total_entregas_base

rank_cidades_entregas = df_bases["Cidade_entrega"].value_counts().reset_index()
rank_cidades_entregas.rename(columns={"index":"cidade", "Cidade_entrega": "qtd_entregas"}, inplace=True)

# %%
grafico, ax = plt.subplots(figsize=(10, 5))
mapa_distrito_federal.plot(ax=ax, alpha=0.4, color="lightgrey")
geo_entregas_df.query("Base == 'df-0'").plot(ax=ax, markersize=1, color="#FFD700", label="df-0")
geo_entregas_df.query("Base == 'df-1'").plot(ax=ax, markersize=1, color="#006400", label="df-1")
geo_entregas_df.query("Base == 'df-2'").plot(ax=ax, markersize=1, color="#00BFFF", label="df-2")
geo_base_df.plot( ax=ax, markersize=10, marker="x", color="black", label="hub" )
plt.title( "Cálculo médio de entregas no Distrito Federal realizadas por Base", fontdict={"fontsize": 14} )
legenda_grafico = plt.legend(prop={"size": 10}, markerscale=5, loc="upper right")

# %% [markdown]
# 1° Insight:
#
# Há uma grande proporção de entregas distantes do hub em funcionamento na região identificada pela cor amarela (<span style="color:#FFD700">df-0</span>). Se o fluxo de entregas continuar aumentando, será necessário construir uma nova base central. Isso atenderá às regiões mais distantes do hub já existente e auxiliará no melhor controle da região mapeada.

# %%
cores_grafico = ['#FFD700', '#006400', '#00BFFF']
grafico_1 = plt.figure(figsize=(10, 5))
total_entregas_grafico = sns.barplot(data=total_entregas_base, x='região', y='total_base', errorbar='sd', palette=cores_grafico)
total_entregas_grafico.set(title='Entregas realizadas por base', xlabel='Bases', ylabel='Volume de entregas')
# Out:
# [Text(0.5, 1.0, 'Entregas realizadas por base'),
#  Text(0.5, 0, 'Bases'),
#  Text(0, 0.5, 'Volume de entregas')]

# %% [markdown]
# 2° Insight:
#
# Ao analisar o gráfico, notamos que a região representada em tom de amarelo (<span style="color:#FFD700">df-0</span>) apresenta um volume de entregas menor em comparação com as outras duas regiões próximas (<span style="color:#006400">df-1</span>) e também a (<span style="color:#00BFFF">df-2</span>). Isso é atribuído à grande distância entre as entregas realizadas nessa região. Este insight é fundamental para compreendermos a distribuição geográfica das nossas operações e para planejar estratégias de logística mais eficientes.

# %%
with sns.axes_style("whitegrid"):
  grafico_2 = plt.figure(figsize=(10, 5))
  grafico_tamanho_entregas = sns.boxplot(x=df_bases["Tamanho_Entrega"], color="#006400")
  grafico_tamanho_entregas.set(title="Tamanho médio das entregas", xlabel="Tamanho das entregas")

# %% [markdown]
# 3° Insight:
#
# Observamos que a maioria das entregas tem um tamanho que varia aproximadamente de 3 a 8. Embora existam entregas com tamanhos que variam de 0,70 a 3 e de 8 a 10, essas são menos comuns e estão fora da faixa média predominante.
